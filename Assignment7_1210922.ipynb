# %% [markdown]
# # Assignment#7

# %% [markdown]
# **Name:** Lama Batta

# %% [markdown]
# **ID:** 1210922

# %% [markdown]
# <span style="color:blue"> **Import Libraries** </span>

# %%
import pandas as pd

# %% [markdown]
# **Describe the data set**

# %% [markdown]
# <span style= "color:red" > **Machine Learning Engineer Salary in 2024 Dataset from kaggle** </span>

# %% [markdown]
# **Feature Description**

# %% [markdown]
# - **work_year:** The year in which the salary data was collected .
# - **experience_level:** The level of experience of the employee .
# - **employment_type:** The type of employment ).
# - **job_title:** The title of the job (e.g., Data Scientist).
# - **salary:** The salary amount.
# - **salary_currency:** The currency in which the salary is denominated.
# - **salary_in_usd:** The salary amount converted to US Dollars.
# - **employee_residence:** The country of residence of the employee.
# - **remote_ratio:** The ratio indicating the level of remote work.
# - **company_location:** The location of the company.
# - **company_size:** The size of the company.

# %% [markdown]
#  **Load the data set**

# %%
# Read data from csv file
df = pd.read_csv('salaries.csv')
df
# Out:
#        work_year experience_level employment_type                 job_title  \
# 0           2024               MI              FT            Data Scientist
# 1           2024               MI              FT            Data Scientist
# 2           2024               MI              CT            Data Scientist
# 3           2024               MI              CT            Data Scientist
# 4           2024               MI              FT      Data Science Manager
# ...          ...              ...             ...                       ...
# 16489       2020               SE              FT            Data Scientist
# 16490       2021               MI              FT  Principal Data Scientist
# 16491       2020               EN              FT            Data Scientist
# 16492       2020               EN              CT     Business Data Analyst
# 16493       2021               SE              FT      Data Science Manager
#
# ...

# %% [markdown]
# **link kaggle for dataset**

# %% [markdown]
# <span style= "color:blue">https://www.kaggle.com/datasets/chopper53/machine-learning-engineer-salary-in-2024</span>

# %% [markdown]
# **The dictionary of the columns**

# %%
# Data Type of columns
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16494 entries, 0 to 16493
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   work_year           16494 non-null  int64
#  1   experience_level    16494 non-null  object
#  2   employment_type     16494 non-null  object
#  3   job_title           16494 non-null  object
#  4   salary              16494 non-null  int64
#  5   salary_currency     16494 non-null  object
#  6   salary_in_usd       16494 non-null  int64
#  7   employee_residence  16494 non-null  object
#  8   remote_ratio        16494 non-null  int64
#  9   company_location    16494 non-null  object
#  10  company_size        16494 non-null  object
# dtypes: int64(4), object(7)
# memory usage: 1.4+ MB

# %% [markdown]
# <span style="color:blue">This result determines the data type for each column integer type  each of the  work_year,salary,salary_in_usd,and remote_ratio features,String type each of the experience_level, employment_type,job_title, salary_currency,employee_residence,company_location,and company_size </span>

# %% [markdown]
# **Data Cleaning**

# %%
Columns_drop={"company_location","remote_ratio","employee_residence"}
df1=df.drop(columns=Columns_drop)
df1
# Out:
#        work_year experience_level employment_type                 job_title  \
# 0           2024               MI              FT            Data Scientist
# 1           2024               MI              FT            Data Scientist
# 2           2024               MI              CT            Data Scientist
# 3           2024               MI              CT            Data Scientist
# 4           2024               MI              FT      Data Science Manager
# ...          ...              ...             ...                       ...
# 16489       2020               SE              FT            Data Scientist
# 16490       2021               MI              FT  Principal Data Scientist
# 16491       2020               EN              FT            Data Scientist
# 16492       2020               EN              CT     Business Data Analyst
# 16493       2021               SE              FT      Data Science Manager
#
# ...

# %% [markdown]
#  <span style="color:blue">**Dropping some columns** </span>

# %%
#cheak the missing value 
df1.isna().sum()
# Out:
# work_year           0
# experience_level    0
# employment_type     0
# job_title           0
# salary              0
# salary_currency     0
# salary_in_usd       0
# company_size        0
# dtype: int64

# %% [markdown]
# <span style="color:blue">The result indicates that there are no missing values for each features </span>

# %%
#Check for duplicates
df1.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 16489    False
# 16490    False
# 16491    False
# 16492    False
# 16493    False
# Length: 16494, dtype: bool

# %% [markdown]
# <span style="color:blue">The result indicates that there are no duplicated values </span>

# %% [markdown]
# **Select Target and Features use to make the prediction**

# %%
# The target we are trying to predict
y = df1['salary']
# The features we will use to make the prediction
X = df1.drop(columns = 'salary')
X
# Out:
#        work_year experience_level employment_type                 job_title  \
# 0           2024               MI              FT            Data Scientist
# 1           2024               MI              FT            Data Scientist
# 2           2024               MI              CT            Data Scientist
# 3           2024               MI              CT            Data Scientist
# 4           2024               MI              FT      Data Science Manager
# ...          ...              ...             ...                       ...
# 16489       2020               SE              FT            Data Scientist
# 16490       2021               MI              FT  Principal Data Scientist
# 16491       2020               EN              FT            Data Scientist
# 16492       2020               EN              CT     Business Data Analyst
# 16493       2021               SE              FT      Data Science Manager
#
#       salary_currency  salary_in_usd company_size
# ...

# %% [markdown]
# **Split data to train and test**

# %%
# Import the train and test split from sklearn
from sklearn.model_selection import train_test_split

# Train test split 
X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=0.2,random_state=1210922)
X_train
# Out:
#        work_year experience_level employment_type                  job_title  \
# 15690       2022               SE              FT             Data Scientist
# 6564        2023               MI              FT             Data Scientist
# 11669       2023               SE              FT             Data Scientist
# 10313       2023               SE              FT              Data Engineer
# 2466        2024               SE              FT             Data Architect
# ...          ...              ...             ...                        ...
# 16226       2022               SE              FT     Applied Data Scientist
# 9389        2023               SE              FT               Data Analyst
# 4156        2024               SE              FT  Machine Learning Engineer
# 1210        2024               SE              FT             Data Architect
# 10950       2023               EX              FT              Data Engineer
#
# ...

# %% [markdown]
# <span style="color:blue">This result is after splitting of the data and using 80% train, making 13195 columns for X_train </span>

# %%
X_test
# Out:
#        work_year experience_level employment_type         job_title  \
# 5915        2024               SE              FT  Research Analyst
# 4408        2024               SE              FT      Data Analyst
# 3038        2024               SE              FT     Data Engineer
# 4692        2024               SE              FT      Data Analyst
# 4966        2024               SE              FT    Data Scientist
# ...          ...              ...             ...               ...
# 16127       2022               SE              FT     Data Engineer
# 2860        2024               EN              FT  Research Analyst
# 6563        2023               MI              FT    Data Scientist
# 8331        2023               SE              FT     Data Engineer
# 8183        2023               SE              FT    Data Scientist
#
#       salary_currency  salary_in_usd company_size
# 5915              USD         150000            M
# ...

# %% [markdown]
# <span style="color:blue">This result is after splitting of the data and using 20% test, making 3299 columns for X_test </span>

# %%
numrical_columns = X_train.select_dtypes("number").columns
ordinal_columns = ['company_size']
nominal_columns = X_train.select_dtypes("object").drop(columns=ordinal_columns).columns

# %% [markdown]
# **Numrical pipeline**

# %%
#import the SimpleImputer ,make_pipeline and StandardScaler from  sklearn
from sklearn.impute import SimpleImputer 
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import OrdinalEncoder
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
# instantiate preprocessors
impute_median = SimpleImputer(strategy='median')
scaler = StandardScaler()

# Make a numeric preprocessing pipeline
numrical_pipe = make_pipeline(impute_median, scaler)
numrical_pipe
# Out:
# Pipeline(steps=[('simpleimputer', SimpleImputer(strategy='median')),
#                 ('standardscaler', StandardScaler())])

# %% [markdown]
# **Ordinal pipline**

# %%
impute_na_ordinal = SimpleImputer(strategy='constant', fill_value='NA')

# Specifying the order of categories in quality/condition columns
company_size_order = ["S", "M", "L"]
# Making the list of order lists for OrdinalEncoder
ordinal_category_orders = [company_size_order]
# Instantiate the encoder and include the list of ordered values as an argument
ordinal_encoder = OrdinalEncoder(categories=ordinal_category_orders)

# Making a final scaler to scale category #'s
scaler_ord = StandardScaler()

ordinal_pipe = make_pipeline(impute_na_ordinal, ordinal_encoder, scaler_ord)

ordinal_pipe
# Out:
# Pipeline(steps=[('simpleimputer',
#                  SimpleImputer(fill_value='NA', strategy='constant')),
#                 ('ordinalencoder',
#                  OrdinalEncoder(categories=[['S', 'M', 'L']])),
#                 ('standardscaler', StandardScaler())])

# %% [markdown]
# **Nominal pipline**

# %%
impute_na_nominal = SimpleImputer(strategy='constant', fill_value = "NA")

# Instantiate one hot encoder
Nominal_encoder = OneHotEncoder(sparse_output=False, handle_unknown='ignore')

# Make pipeline with imputer and encoder
Nominal_pipe = make_pipeline(impute_na_nominal,Nominal_encoder )
Nominal_pipe
# Out:
# Pipeline(steps=[('simpleimputer',
#                  SimpleImputer(fill_value='NA', strategy='constant')),
#                 ('onehotencoder',
#                  OneHotEncoder(handle_unknown='ignore', sparse_output=False))])

# %% [markdown]
# **Build pipelines tuples**

# %%
from sklearn import set_config
set_config(transform_output='pandas')
numrical_tuple = ('numeric', numrical_pipe, numrical_columns)
ordinal_tuple = ('ordinal', ordinal_pipe, ordinal_columns)
Nominal_tuple = ('categorical', Nominal_pipe, nominal_columns)


# Create ColumnTransformer
# Instantiate with verbose_feature_names_out=False 
col_transformer = ColumnTransformer([numrical_tuple, ordinal_tuple, Nominal_tuple],
                                    verbose_feature_names_out=False)

# Fit on training data
col_transformer.fit(X_train)
# Transform the training data
X_train_transformer = col_transformer.transform(X_train)
# Transform the testing data
X_test_transformer = col_transformer.transform(X_test)
# View the processed training data
X_train_transformer
# Out:
#        work_year  salary_in_usd  company_size  experience_level_EN  \
# 15690  -1.725631      -0.123245     -0.189427                  0.0
# 6564   -0.319920      -0.909508     -0.189427                  0.0
# 11669  -0.319920       2.992390     -0.189427                  0.0
# 10313  -0.319920      -0.359804     -0.189427                  0.0
# 2466    1.085790       1.316508     -0.189427                  0.0
# ...          ...            ...           ...                  ...
# 16226  -1.725631       0.384587      3.530047                  0.0
# 9389   -0.319920      -1.268534     -0.189427                  0.0
# 4156    1.085790       2.488924     -0.189427                  0.0
# 1210    1.085790      -0.600300     -0.189427                  0.0
# 10950  -0.319920      -1.119827     -0.189427                  0.0
#
#        experience_level_EX  experience_level_MI  experience_level_SE  \
# 15690                  0.0                  0.0                  1.0
# ...

# %% [markdown]
# <span style="color:e">**Fit a linear regression model on the transformed data.** </span>

# %%
from sklearn.linear_model import LinearRegression
# from sklearn.linear_model SGDRegressor
model = LinearRegression()
model_pipe = make_pipeline(col_transformer, model)
# Fit the model on the training data
model_pipe.fit(X_train, y_train)
model_pipe
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(transformers=[('numeric',
#                                                   Pipeline(steps=[('simpleimputer',
#                                                                    SimpleImputer(strategy='median')),
#                                                                   ('standardscaler',
#                                                                    StandardScaler())]),
#                                                   Index(['work_year', 'salary_in_usd'], dtype='object')),
#                                                  ('ordinal',
#                                                   Pipeline(steps=[('simpleimputer',
#                                                                    SimpleImputer(fill_value='NA',
#                                                                                  strategy='constant')),
# ...

# %% [markdown]
# <span style="color:red">**Print the model parameters and provide an interpretation for each.** </span>

# %%
b_0 = model.intercept_.round(2)
b_i = model.coef_.round(2)
feature_names = col_transformer.get_feature_names_out()
eq = " +\n".join([ f"{'' if i == 0 else ' '*24}{b_i[i]} * {feature_names[i]}"  for i in range(len(feature_names))])
print(f"Model equation: y_hat = {eq}")
# Out:
# Model equation: y_hat = 667.28 * work_year +
#                         69707.91 * salary_in_usd +
#                         4196.81 * company_size +
#                         4363015412504446.5 * experience_level_EN +
#                         4363015412503638.0 * experience_level_EX +
#                         4363015412507001.5 * experience_level_MI +
#                         4363015412511611.5 * experience_level_SE +
#                         723973630295157.2 * employment_type_CT +
#                         723973630269081.5 * employment_type_FL +
#                         723973630267254.4 * employment_type_FT +
#                         723973630274120.0 * employment_type_PT +
#                         -6509529641227.82 * job_title_AI Architect +
#                         -6509529635229.92 * job_title_AI Developer +
#                         -6509529643466.95 * job_title_AI Engineer +
#                         -6509529645996.16 * job_title_AI Product Manager +
# ...

# %% [markdown]
# **Interpret**

# %% [markdown]
# - **667.28 (work_year):**

# %% [markdown]
#  <span style="color:blue">When the work year incease by one year, the salary expected to increase by 667.28. </span>

# %% [markdown]
# - **69707.91 (salary_in_usd):**

# %% [markdown]
#  <span style="color:blue">When the salary_in_usd incease by one usd , the salary expected to increase by 69707.91. </span>

# %% [markdown]
# - **4196.81 (company_size):**

# %% [markdown]
# <span style="color:blue">When the company_size incease by one size , the salary expected to increase by 4196.81. </span>

# %% [markdown]
# -  **4363015412504446.5(experience_level_EN):**

# %% [markdown]
# <span style="color:blue">When the increases experience_level_EN by one level ,the salary expected to increases by 4363015412504446.5. </span>

# %% [markdown]
# -  **4363015412503638.0(experience_level_EX):**

# %% [markdown]
# <span style="color:blue">When the increases experience_level_Ex by one level ,the salary expected to increases by 4363015412503638.0. </span>

# %% [markdown]
# -  **4363015412507001.5(experience_level_MI):**

# %% [markdown]
# <span style="color:blue">When the increases experience_level_MI by one level ,the salary expected to increases by  4363015412507001.5. </span>

# %% [markdown]
# -  **4363015412511611.5(experience_level_SE):**

# %% [markdown]
# <span style="color:blue">When the increases experience_level_SE by one level ,the salary expected to increases by 4363015412511611.5. </span>

# %% [markdown]
# - **723973630295157.2 (employment_type_CT)**

# %% [markdown]
# <span style="color:blue">When the employment_type change to CT ,the salary expected to increases by 723973630295157.2. </span>

# %% [markdown]
# - **723973630269081.5 (employment_type_FL)**

# %% [markdown]
# <span style="color:blue">When the employment_type change to FL ,the salary expected to increases by  723973630269081.5. </span>

# %% [markdown]
# - **723973630267254.4 (employment_type_FT)**

# %% [markdown]
# <span style="color:blue">When the employment_type change to FT ,the salary expected to increases by 723973630267254.4. </span>

# %% [markdown]
# - **723973630274120.0. (employment_type_PT)**

# %% [markdown]
# <span style="color:blue">When the employment_type change to PT ,the salary expected to increases by 723973630274120.0. </span>

# %% [markdown]
# <span style="color:red">**Evaluate the model's quality using appropriate metrics.** </span>

# %%
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
def regression_metrics(y_true, y_pred, label='', verbose = True, output_dict=False):
    # Get metrics
    mae = mean_absolute_error(y_true, y_pred)
    mse = mean_squared_error(y_true, y_pred)
    rmse = mean_squared_error(y_true, y_pred, squared=False) 
    r_squared = r2_score(y_true, y_pred)
    if verbose == True:
        # Print Result with Label and Header
        header = "-"*60
        print(header, f"Regression Metrics: {label}", header, sep='\n')
        print(f"- MAE = {mae:,.3f}")
        print(f"- MSE = {mse:,.3f}")
        print(f"- RMSE = {rmse:,.3f}")
        print(f"- R^2 = {r_squared:,.3f}")
    if output_dict == True:
        metrics = {'Label':label, 'MAE':mae,
                 'MSE':mse, 'RMSE':rmse, 'R^2':r_squared}
        
        
# Get predictions for training data
y_train_pred = model_pipe.predict(X_train)

# Call the helper function to obtain regression metrics for training data
results_train = regression_metrics(y_train, y_train_pred, label='Training Data')
print()
# Get predictions for test data
y_test_pred = model_pipe.predict(X_test)
# Call the helper function to obtain regression metrics for test data
results_test = regression_metrics(y_test, y_test_pred, label='Test Data' )
# Out:
# ------------------------------------------------------------
# Regression Metrics: Training Data
# ------------------------------------------------------------
# - MAE = 10,042.939
# - MSE = 6,826,010,990.508
# - RMSE = 82,619.677
# - R^2 = 0.943
#
# ------------------------------------------------------------
# Regression Metrics: Test Data
# ------------------------------------------------------------
# - MAE = 10,982,907,285,728.592
# - MSE = 20,902,771,842,190,501,550,240,038,912.000
# - RMSE = 144,577,909,246,850.375
# - R^2 = -203,767,075,040,839,232.000
# C:\Users\user\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# ...

# %% [markdown]
# <span style="color:red">**Determine if the model exhibits overfitting or underfitting and explain your reasoning.** </span>

# %% [markdown]
# <span style="color:blue">According to the results that appeared, the value of RMSE in Training Data is 82,619.677 and its value in Test Data has become 144,577,909,246,850.375. This means that it is increasing, so the model is overfitting. </span>
